# %%
import json
from ibm_watson import NaturalLanguageUnderstandingV1
from ibm_cloud_sdk_core.authenticators import IAMAuthenticator
from ibm_watson.natural_language_understanding_v1 import\
    Features, EntitiesOptions, KeywordsOptions, CategoriesOptions,\
    SyntaxOptions, SyntaxOptionsTokens
import os

# %% [markdown]
# # Setup SDK connection

# %%
api_creds = {
  "apikey": os.environ['IBM_APIKEY'],
  "url": os.environ['IBM_APIURL']
}

authenticator = IAMAuthenticator(api_creds['apikey'])
ibm_nlp = NaturalLanguageUnderstandingV1(
    version='2020-08-01',
    authenticator=authenticator
)

ibm_nlp.set_service_url(api_creds['url'])

# %% [markdown]
# # Setup Test Text

# %%
test_text = 'Sem a menor mudança de voz, Ireneo disse-me o que se passara. Estava na cama, funmando. Parece-me que não vi o seu rosto até a aurora; creio lembrar-me da brasa momentânea do cigarro. O quarto exalava um vago odor de umidade. Sentei-me, repeti a história do telegrama e da enfermidade de meu pai.'

# %% [markdown]
# # ~~Topic Modelling~~ Categories

# %%
response = ibm_nlp.analyze(
    text=test_text,
    features=Features(categories=CategoriesOptions(limit=5))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 296,
#     "features": 1
#   },
#   "language": "pt",
#   "categories": [
#     {
#       "score": 0.868511,
#       "label": "/health and fitness/addiction/smoking addiction"
#     },
#     {
#       "score": 0.865566,
#       "label": "/sports/scuba diving"
#     },
#     {
#       "score": 0.761057,
#       "label": "/sports/diving"
#     }
#   ]
# }

# %% [markdown]
# # Named Entity Extraction

# %%
response = ibm_nlp.analyze(
    text=test_text,
    features=Features(entities=EntitiesOptions(sentiment=True,limit=5))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 296,
#     "features": 1
#   },
#   "language": "pt",
#   "entities": [
#     {
#       "type": "Person",
#       "text": "Ireneo",
#       "sentiment": {
#         "score": 0,
#         "label": "neutral"
#       },
#       "relevance": 0.963296,
#       "count": 1,
#       "confidence": 0.998707
#     },
#     {
#       "type": "Ordinal",
#       "text": "quarto",
#       "sentiment": {
#         "score": -0.719312,
#         "label": "negative"
#       },
#       "relevance": 0.163102,
#       "count": 1,
#       "confidence": 0.702622
#     }
#   ]
# }

# %%
def print_entities(text):
    response = ibm_nlp\
        .analyze(
            text=text,
            features=
                Features(
                    entities=EntitiesOptions(
                    sentiment=True,
                    limit=5
                )
            )
        ).get_result()
    for entity in response['entities']:
            # print(entity)
            print(f'\t {entity["text"]} -> '
                  f'category: {entity["type"]} '
                  f'| score: {entity["confidence"]}')

# %%
print_entities(test_text)
# Out:
# 	 Ireneo -> category: Person | score: 0.998707
# 	 quarto -> category: Ordinal | score: 0.702622

# %% [markdown]
# # Keywords

# %%
response = ibm_nlp\
    .analyze(
        text=test_text,
        features=Features(
            keywords=KeywordsOptions(
                sentiment=False,
                emotion=False,
                limit=5
            )
        )
    ).get_result()

# %%
print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 296,
#     "features": 1
#   },
#   "language": "pt",
#   "keywords": [
#     {
#       "text": "menor mudan\u00e7a de voz",
#       "relevance": 0.879845,
#       "count": 1
#     },
#     {
#       "text": "hist\u00f3ria do telegrama",
#       "relevance": 0.586987,
#       "count": 1
#     },
#     {
#       "text": "vago odor de umidade",
#       "relevance": 0.565728,
#       "count": 1
#     },
#     {
#       "text": "brasa moment\u00e2nea do cigarro",
#       "relevance": 0.558644,
#       "count": 1
#     },
#     {
#       "text": "enfermidade de meu pai",
#       "relevance": 0.488795,
#       "count": 1
#     }
#   ]
# }

# %% [markdown]
# # Syntax

# %%
response = ibm_nlp.analyze(
    text=test_text,
    features=Features(
      syntax=SyntaxOptions(
        sentences=True,
        tokens=SyntaxOptionsTokens(
          lemma=True,
          part_of_speech=False,
        )))).get_result()

print(json.dumps(response, indent=2))
# Out:
# {
#   "usage": {
#     "text_units": 1,
#     "text_characters": 296,
#     "features": 1
#   },
#   "syntax": {
#     "tokens": [
#       {
#         "text": "Sem",
#         "location": [
#           0,
#           3
#         ],
#         "lemma": "sem"
#       },
#       {
#         "text": "a",
#         "location": [
#           4,
#           5
#         ],
#         "lemma": "o"
#       },
#       {
#         "text": "menor",
#         "location": [
#           6,
#           11
#         ],
#         "lemma": "menor"
#       },
#       {
#         "text": "mudan\u00e7a",
#         "location": [
#           12,
#           19
#         ],
#         "lemma": "mudan\u00e7a"
#       },
#       {
#         "text": "de",
#         "location": [
#           20,
#           22
#         ],
#         "lemma": "de"
#       },
#       {
#         "text": "voz",
#         "location": [
#           23,
#           26
#         ],
#         "lemma": "voz"
#       },
#       {
#         "text": ",",
#         "location": [
#           26,
#           27
#         ]
#       },
#       {
#         "text": "Ireneo",
#         "location": [
#           28,
#           34
#         ]
#       },
#       {
#         "text": "disse",
#         "location": [
#           35,
#           40
#         ],
#         "lemma": "dizer"
#       },
#       {
#         "text": "-me",
#         "location": [
#           40,
#           43
#         ],
#         "lemma": "eu"
#       },
#       {
#         "text": "o",
#         "location": [
#           44,
#           45
#         ],
#         "lemma": "ele"
#       },
#       {
#         "text": "que",
#         "location": [
#           46,
#           49
#         ],
#         "lemma": "que"
#       },
#       {
#         "text": "se",
#         "location": [
#           50,
#           52
#         ],
#         "lemma": "ele"
#       },
#       {
#         "text": "passara",
#         "location": [
#           53,
#           60
#         ],
#         "lemma": "passar"
#       },
#       {
#         "text": ".",
#         "location": [
#           60,
#           61
#         ]
#       },
#       {
#         "text": "Estava",
#         "location": [
#           62,
#           68
#         ],
#         "lemma": "estar"
#       },
#       {
#         "text": "na",
#         "location": [
#           69,
#           71
#         ],
#         "lemma": "no"
#       },
#       {
#         "text": "cama",
#         "location": [
#           72,
#           76
#         ],
#         "lemma": "cama"
#       },
#       {
#         "text": ",",
#         "location": [
#           76,
#           77
#         ]
#       },
#       {
#         "text": "funmando",
#         "location": [
#           78,
#           86
#         ]
#       },
#       {
#         "text": ".",
#         "location": [
#           86,
#           87
#         ]
#       },
#       {
#         "text": "Parece",
#         "location": [
#           88,
#           94
#         ],
#         "lemma": "parecer"
#       },
#       {
#         "text": "-me",
#         "location": [
#           94,
#           97
#         ],
#         "lemma": "eu"
#       },
#       {
#         "text": "que",
#         "location": [
#           98,
#           101
#         ],
#         "lemma": "que"
#       },
#       {
#         "text": "n\u00e3o",
#         "location": [
#           102,
#           105
#         ],
#         "lemma": "n\u00e3o"
#       },
#       {
#         "text": "vi",
#         "location": [
#           106,
#           108
#         ],
#         "lemma": "ver"
#       },
#       {
#         "text": "o",
#         "location": [
#           109,
#           110
#         ],
#         "lemma": "o"
#       },
#       {
#         "text": "seu",
#         "location": [
#           111,
#           114
#         ],
#         "lemma": "seu"
#       },
#       {
#         "text": "rosto",
#         "location": [
#           115,
#           120
#         ],
#         "lemma": "rosto"
#       },
#       {
#         "text": "at\u00e9",
#         "location": [
#           121,
#           124
#         ],
#         "lemma": "at\u00e9"
#       },
#       {
#         "text": "a",
#         "location": [
#           125,
#           126
#         ],
#         "lemma": "o"
#       },
#       {
#         "text": "aurora",
#         "location": [
#           127,
#           133
#         ],
#         "lemma": "aurora"
#       },
#       {
#         "text": ";",
#         "location": [
#           133,
#           134
#         ]
#       },
#       {
#         "text": "creio",
#         "location": [
#           135,
#           140
#         ],
#         "lemma": "crer"
#       },
#       {
#         "text": "lembrar",
#         "location": [
#           141,
#           148
#         ],
#         "lemma": "lembrar"
#       },
#       {
#         "text": "-me",
#         "location": [
#           148,
#           151
#         ],
#         "lemma": "eu"
#       },
#       {
#         "text": "da",
#         "location": [
#           152,
#           154
#         ],
#         "lemma": "do"
#       },
#       {
#         "text": "brasa",
#         "location": [
#           155,
#           160
#         ],
#         "lemma": "brasa"
#       },
#       {
#         "text": "moment\u00e2nea",
#         "location": [
#           161,
#           171
#         ],
#         "lemma": "moment\u00e2neo"
#       },
#       {
#         "text": "do",
#         "location": [
#           172,
#           174
#         ],
#         "lemma": "do"
#       },
#       {
#         "text": "cigarro",
#         "location": [
#           175,
#           182
#         ],
#         "lemma": "cigarro"
#       },
#       {
#         "text": ".",
#         "location": [
#           182,
#           183
#         ]
#       },
#       {
#         "text": "O",
#         "location": [
#           184,
#           185
#         ],
#         "lemma": "o"
#       },
#       {
#         "text": "quarto",
#         "location": [
#           186,
#           192
#         ],
#         "lemma": "quarto"
#       },
#       {
#         "text": "exalava",
#         "location": [
#           193,
#           200
#         ],
#         "lemma": "exalar"
#       },
#       {
#         "text": "um",
#         "location": [
#           201,
#           203
#         ],
#         "lemma": "um"
#       },
#       {
#         "text": "vago",
#         "location": [
#           204,
#           208
#         ],
#         "lemma": "vago"
#       },
#       {
#         "text": "odor",
#         "location": [
#           209,
#           213
#         ],
#         "lemma": "odor"
#       },
#       {
#         "text": "de",
#         "location": [
#           214,
#           216
#         ],
#         "lemma": "de"
#       },
#       {
#         "text": "umidade",
#         "location": [
#           217,
#           224
#         ],
#         "lemma": "umidade"
#       },
#       {
#         "text": ".",
#         "location": [
#           224,
#           225
#         ]
#       },
#       {
#         "text": "Sentei",
#         "location": [
#           226,
#           232
#         ],
#         "lemma": "sentar"
#       },
#       {
#         "text": "-me",
#         "location": [
#           232,
#           235
#         ],
#         "lemma": "eu"
#       },
#       {
#         "text": ",",
#         "location": [
#           235,
#           236
#         ]
#       },
#       {
#         "text": "repeti",
#         "location": [
#           237,
#           243
#         ],
#         "lemma": "repetir"
#       },
#       {
#         "text": "a",
#         "location": [
#           244,
#           245
#         ],
#         "lemma": "o"
#       },
#       {
#         "text": "hist\u00f3ria",
#         "location": [
#           246,
#           254
#         ],
#         "lemma": "hist\u00f3ria"
#       },
#       {
#         "text": "do",
#         "location": [
#           255,
#           257
#         ],
#         "lemma": "do"
#       },
#       {
#         "text": "telegrama",
#         "location": [
#           258,
#           267
#         ],
#         "lemma": "telegrama"
#       },
#       {
#         "text": "e",
#         "location": [
#           268,
#           269
#         ],
#         "lemma": "e"
#       },
#       {
#         "text": "da",
#         "location": [
#           270,
#           272
#         ],
#         "lemma": "do"
#       },
#       {
#         "text": "enfermidade",
#         "location": [
#           273,
#           284
#         ],
#         "lemma": "enfermidade"
#       },
#       {
#         "text": "de",
#         "location": [
#           285,
#           287
#         ],
#         "lemma": "de"
#       },
#       {
#         "text": "meu",
#         "location": [
#           288,
#           291
#         ],
#         "lemma": "meu"
#       },
#       {
#         "text": "pai",
#         "location": [
#           292,
#           295
#         ],
#         "lemma": "pai"
#       },
#       {
#         "text": ".",
#         "location": [
#           295,
#           296
#         ]
#       }
#     ],
#     "sentences": [
#       {
#         "text": "Sem a menor mudan\u00e7a de voz, Ireneo disse-me o que se passara.",
#         "location": [
#           0,
#           61
#         ]
#       },
#       {
#         "text": "Estava na cama, funmando.",
#         "location": [
#           62,
#           87
#         ]
#       },
#       {
#         "text": "Parece-me que n\u00e3o vi o seu rosto at\u00e9 a aurora; creio lembrar-me da brasa moment\u00e2nea do cigarro.",
#         "location": [
#           88,
#           183
#         ]
#       },
#       {
#         "text": "O quarto exalava um vago odor de umidade.",
#         "location": [
#           184,
#           225
#         ]
#       },
#       {
#         "text": "Sentei-me, repeti a hist\u00f3ria do telegrama e da enfermidade de meu pai.",
#         "location": [
#           226,
#           296
#         ]
#       }
#     ]
#   },
#   "language": "pt"
# }
